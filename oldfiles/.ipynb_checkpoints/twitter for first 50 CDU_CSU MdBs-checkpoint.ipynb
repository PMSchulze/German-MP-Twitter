# %%
import pickle
import pandas as pd
import numpy as np

with open(r'C:\Users\Simon\OneDrive\Uni\LMU\SS 2020\Statistisches Consulting\Bundestag-MP-Analyse\abg_df.pickle', 'rb') as handle:
    df = pickle.load(handle)

# %%
j = 0
for i in range(len(df)):
    if df['Partei'][i] == "CDU/CSU":
        print(j, df['Name'][i])
        j += 1
        if "Twitter" in df['Soziale Medien'][i]:
            print(df['Soziale Medien'][i]['Twitter'])
# Out:
# 0 Abercron, Dr. Michael von
# https://twitter.com/mvabercron/
# 1 Albani, Stephan
# 2 Altenkamp, Norbert
# 3 Altmaier, Peter
# https://twitter.com/peteraltmaier
# 4 Amthor, Philipp
# 5 Auernhammer, Artur
# 6 Aumer, Peter
# 7 Bär, Dorothee
# 8 Bareiß, Thomas
# 9 Barthle, Norbert
# 10 Beermann, Maik
# 11 Behrens (Börde), Manfred
# 12 Bellmann, Veronika
# 13 Benning, Sybille
# 14 Berghegger, Dr. André
# 15 Bernstein, Melanie
# 16 Bernstiel, Christoph
# 17 Beyer, Peter
# 18 Biadacz, Marc
# https://twitter.com/MBiadaczMdB
# 19 Bilger, Steffen
# https://twitter.com/steffenbilger
# 20 Bleser, Peter
# 21 Brackmann, Norbert
# 22 Brand (Fulda), Michael
# 23 Brandl, Dr. Reinhard
# 24 Braun, Prof. Dr. Helge
# 25 Breher, Silvia
# 26 Brehm, Sebastian
# https://twitter.com/Brehm_inNBGNord
# 27 Brehmer, Heike
# 28 Brinkhaus, Ralph
# http://www.twitter.com/rbrinkhaus
# 29 Brodesser, Dr. Carsten
# 30 Connemann, Gitta
# 31 Damerow, Astrid
# 32 Dobrindt, Alexander
# 33 Dött, Marie-Luise
# ...

# %%
# CDU/CSU twitter accounts
cdu_csu_twitter_list = []
for i in range(len(df)):
    if df['Partei'][i] == "CDU/CSU":
        if "Twitter" in df['Soziale Medien'][i]:
            cdu_csu_twitter_list.append([df['Name'][i], df['Soziale Medien'][i]['Twitter']])
        else:
            cdu_csu_twitter_list.append([df['Name'][i]])

# %%
# manually adding twitter accounts for the first 50 CDU/CSU MdBs
cdu_csu_twitter_list[6].append('https://twitter.com/peteraumer')
cdu_csu_twitter_list[7].append('https://twitter.com/dorobaer')
cdu_csu_twitter_list[8].append('https://twitter.com/Thomas_Bareiss')
cdu_csu_twitter_list[10].append('https://twitter.com/MaikBeermann')
cdu_csu_twitter_list[11].append('https://twitter.com/manfredbehrens')
cdu_csu_twitter_list[13].append('https://twitter.com/SybilleBenning')
cdu_csu_twitter_list[16].append('https://twitter.com/c_bernstiel')
cdu_csu_twitter_list[17].append('https://twitter.com/Peter_Beyer')
cdu_csu_twitter_list[23].append('https://twitter.com/reinhardbrandl')
cdu_csu_twitter_list[24].append('https://twitter.com/HBraun')
cdu_csu_twitter_list[27].append('https://twitter.com/HeikeBrehmerMdB')
cdu_csu_twitter_list[30].append('https://twitter.com/gitta_connemann')
cdu_csu_twitter_list[35].append('https://twitter.com/hansjoerg_durz')
cdu_csu_twitter_list[36].append('https://twitter.com/terndl')
cdu_csu_twitter_list[38].append('https://twitter.com/uwefeilermdb')
cdu_csu_twitter_list[40].append('https://twitter.com/axel_fischer')
cdu_csu_twitter_list[44].append('https://twitter.com/hpfriedrichcsu')
cdu_csu_twitter_list[45].append('https://twitter.com/MichaelFrieser')
cdu_csu_twitter_list[46].append('https://twitter.com/fuchtel')
cdu_csu_twitter_list[48].append('https://twitter.com/thomasgebhart')

# %%
cdu_csu_twitter_list
# Out:
# [['Abercron, Dr. Michael von', 'https://twitter.com/mvabercron/'],
#  ['Albani, Stephan'],
#  ['Altenkamp, Norbert'],
#  ['Altmaier, Peter', 'https://twitter.com/peteraltmaier'],
#  ['Amthor, Philipp'],
#  ['Auernhammer, Artur'],
#  ['Aumer, Peter', 'https://twitter.com/peteraumer'],
#  ['Bär, Dorothee', 'https://twitter.com/dorobaer'],
#  ['Bareiß, Thomas', 'https://twitter.com/Thomas_Bareiss'],
#  ['Barthle, Norbert'],
#  ['Beermann, Maik', 'https://twitter.com/MaikBeermann'],
#  ['Behrens (Börde), Manfred', 'https://twitter.com/manfredbehrens'],
#  ['Bellmann, Veronika'],
#  ['Benning, Sybille', 'https://twitter.com/SybilleBenning'],
#  ['Berghegger, Dr. André'],
#  ['Bernstein, Melanie'],
#  ['Bernstiel, Christoph', 'https://twitter.com/c_bernstiel'],
#  ['Beyer, Peter', 'https://twitter.com/Peter_Beyer'],
#  ['Biadacz, Marc', 'https://twitter.com/MBiadaczMdB'],
#  ['Bilger, Steffen', 'https://twitter.com/steffenbilger'],
#  ['Bleser, Peter'],
#  ['Brackmann, Norbert'],
# ...
